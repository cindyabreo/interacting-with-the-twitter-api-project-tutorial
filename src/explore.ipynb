# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-4.10.0-py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.4/94.4 kB 2.0 MB/s eta 0:00:000:00:01
# Collecting oauthlib<4,>=3.2.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 3.9 MB/s eta 0:00:0031m23.6 MB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.27.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from tweepy) (2.27.1)
# Collecting requests-oauthlib<2,>=1.2.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests<3,>=2.27.0->tweepy) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests<3,>=2.27.0->tweepy) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from requests<3,>=2.27.0->tweepy) (1.26.9)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.2.0 requests-oauthlib-1.3.1 tweepy-4.10.0
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy 
import requests

# %%
userkey='wZHyt0zmjQho8U3Db5ws5z52p'
keysecret='8wlKAA92gcSyVfAgLxChVVRQ5PiV61JwIeZHKLmhzwkabz2fV7'
bearertoken='AAAAAAAAAAAAAAAAAAAAACKGdwEAAAAABXLmtxnxH%2FhGvMK6KJGk5UQxJeE%3D8dddsAMNXHhUMWHzG6gUVZArPnc6BvAB4SzwuyZkZp2EGlU99E'


#client=tweepy.Client(bearer_token=bearertoken, consumer_key=userkey, consumer_secret='202753071-aSAV4jAEZcJ3TPOWEwVhYBj7ZeArdtWCqmEDwAqW', access_token=keysecret, access_secret='7XaXXeJsgukicNuwsBBbu1eP41AnfBliPv68VQIxnH1Dj', return_type= requests.Response, weit_on_reit_limit=True)

# %%
client = tweepy.Client(bearer_token=bearertoken,
consumer_key="wZHyt0zmjQho8U3Db5ws5z52p",
consumer_secret="AAAAAAAAAAAAAAAAAAAAACKGdwEAAAAABXLmtxnxH%2FhGvMK6KJGk5UQxJeE%3D8dddsAMNXHhUMWHzG6gUVZArPnc6BvAB4SzwuyZkZp2EGlU99E",
access_token="202753071-aSAV4jAEZcJ3TPOWEwVhYBj7ZeArdtWCqmEDwAqW",
access_token_secret="202753071-aSAV4jAEZcJ3TPOWEwVhYBj7ZeArdtWCqmEDwAqW",
return_type=requests.Response,
wait_on_rate_limit=True
)

# %%
query='#100daysofcode (pandas OR python) -is:retweet'

# %%
query
# Out:
# '#100daysofcode (pandas OR python) -is:retweet'

# %%
tweets=client.search_recent_tweets(query=query,tweet_fields=['author_id','created_at','lang'],max_results=100)

# %%
tweets_json=tweets.json()

# %%
print(tweets_json)
# Out:
# {'data': [{'created_at': '2022-07-22T21:32:08.000Z', 'lang': 'en', 'author_id': '818797380929724416', 'id': '1550594569275940865', 'text': "Day 5 of #100DaysOfCode \n\nI don't know how I forgot yesterday's tweet :) Sorry for that.\n\nYesterday's lesson was about Python Loops.\n\nUsing for loop, range function etc.\n\nI made a password generator with loops.\n\nhttps://t.co/ip4L3tFGvv\n\n#LearnProgramming\n#100daysofcodechallenge"}, {'created_at': '2022-07-22T21:30:27.000Z', 'lang': 'en', 'author_id': '1343372118', 'id': '1550594143428087808', 'text': 'We deliver unique work 🚨   \n 🔫 DM for value-based services  \n #essaywrite \n #essaywrite \n #essaywrite \n #100DaysOfCode\n #homework \n #Case study\n #Homework  \n #Econometrics\n #Math \n #100DaysOfCode \n #essaywrite \n #python \n 🏡 \n 👄 \n\n https://t.co/MrEPSqHB5x'}, {'created_at': '2022-07-22T21:29:14.000Z', 'lang': 'en', 'author_id': '1529052664251678721', 'id': '1550593837986418696', 'text': 'A complete overview on #python lists!\nLet me know in the comments what do you think about it!\nhttps://t.co/DJjygrHFH0\n\n#development #developers #programming #programmers #Python3 #learning #LearningAndDevelopment #blog #Blogs #tutorial #100DaysOfCode #100daysofcodechallenge'}, {'created_at': '2022-07-22T21:29:07.000Z', 'lang': 'en', 'author_id': '1263264007886176257', 'id': '1550593808252841984', 'text': 'Looking for a tutor to take your final exams?\nGet online class #Assignmenthelp\n#Paperpay\n#python\n#homework\n#Onlineclass\n#Essaypay\n#100DaysOfCode\n#Econometrics\n#Math\n#homework\n#essaywrite\n#Casestudy\n#javascript\n#Homework\n#Philosophy\n\n#essayhelp\n#nickiday #NFLnaESPN #ASUTwitter'}, {'created_at': '2022-07-22T21:29:04.000Z', 'lang': 'en', 'author_id': '1263264007886176257', 'id': '1550593796299452416', 'text': 'Get online class exam help \n\nFinal exams\nFull course\nEssays \nAssignments.\nDissertation\nResearch Projects\nProof feeding\nPersonal statements\n\n#MachineLearning #5G #DataScience #tech #100DaysOfCode\n#Python #Cybersecurity #BigData #AI #IoT #DeepLearning\n#ArtificialIntelligence #NLP'}, {'created_at': '2022-07-22T21:28:09.000Z', 'lang': 'en', 'author_id': '1949360875', 'id': '1550593564672811009', 'text': "#Fresh #chillout #bass #edm #tune: City Lights - Chris Tuttle | #Retweet #AI #rtitbot '@BlazedRTs '@RexRTs '@sme_rt #SpotifyRT #php #react #python #nodejs #flutter #webdev #100daysofcode #sound #design #coding | #Buy the #music https://t.co/YjhHw2ZZw3"}, {'created_at': '2022-07-22T21:25:14.000Z', 'lang': 'en', 'author_id': '836510570', 'id': '1550592831852511232', 'text': 'Best #programming languages for #DataScience\nVia @ingliguori\n#Python #MachineLearning #python #IoT #100DaysOfCode #CodeNewbie #reactjs #bugbounty #gamedev #BigData #Analytics #NeuralNetworks #Cloud #OpenSource #AI #SQL #Scala #DEVCommunity #codinglife #R #Java https://t.co/r5ws36zVbi'}, {'created_at': '2022-07-22T21:24:47.000Z', 'lang': 'qme', 'author_id': '3003891575', 'id': '1550592720669908993', 'text': '#MachineLearning #DataScience #SQL #Cybersecurity #BigData #Analytics #AI #IIoT #Python #RStats #TensorFlow #JavaScript #ReactJS #CloudComputing #Serverless #DataScientist #Linux #Programming #Coding #100DaysofCode #NodeJS #GitHub #IoT \nhttps://t.co/gQrQ2zsbuX'}, {'created_at': '2022-07-22T21:23:59.000Z', 'lang': 'en', 'author_id': '1547574120841285633', 'id': '1550592517879599150', 'text': 'Day 8 of learning python\n-Handling Errors\nLearnt about\n*Being specific about exception\n*Keeping your App from crashing\n*Using try and except\nWith what I have learnt so far I built two programs( Madlib and Guessing game)\n#100DaysOfCode \n#100daysofcodechallenge \n#100daysofpython'}, {'created_at': '2022-07-22T21:23:18.000Z', 'lang': 'en', 'author_id': '1504921682024308739', 'id': '1550592347162959873', 'text': "@cloudysizzler Hire us to secure you A's in your essays.\n#pay someone\nMaths\n#Serverless\nPhysics\n#essayhelp\n#essaypay\nMaths\n#Essaydue\nChemistry\n#100DaysOfCode\nNur ...

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.4.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 60.0 MB/s eta 0:00:00m eta 0:00:01:01
# Collecting numpy>=1.18.5
#   Downloading numpy-1.23.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 52.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 kB 10.3 MB/s eta 0:00:00m eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.23.1 pandas-1.4.3 pytz-2022.1
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspace/interacting-with-the-twitter-api-project-tutorial/src/explore.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://cindyabreo-interactingw-aawhxbod0kg.ws-us54.gitpod.io/workspace/interacting-with-the-twitter-api-project-tutorial/src/explore.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
tweets_data=tweets_json['data']
df=pd.json_normalize(tweets_data)
print(df)
